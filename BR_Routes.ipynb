# %%
#THE FOLLOWING FLOORPLANS PERTAIN TO BRADLEY HALL

# %%
import math
import heapq

BH0_floorplan={
    #entry nodes
    "stairR1": {"Hallway1": 3},
    "stairL1": {"Hallway1": 3},
    "stairL2":{"leftHallway1":3},
    "elevator":{"leftHallway1":3},
    "stairR3":{"rightHallway2":2},
    "stairR2": {"Hallway3": 2},

    #hall nodes
    "Hallway1":{"BR040":1,"BR045":1,"BR047":2,"BR043":2,"BR041":2,"BR029":2,"Lwomens":2,"BR025":3,"BR010":4,"BR015":5,
                "stairL1":3,"BR026":3,"BR032":2,"BR046":2,"BR048":3,"BR050":3,"stairR1":3,"BR070":4,"BR080":4,"BR083":5,
                "leftHallway1":4,"leftHallway2":5,"rightHallway1":2,"rightHallway2":4,"rightHallway3":5},
    
    "leftHallway1": {"BR001":3,"BR003":3,"BR010":2,"BR018":1,"BR023":2,"BR024":2,"BR067":3,"BR068":3,"elevator":3,"stairL2":3,
                     "Hallway1":2,"Hallway2":2},

    "leftHallway2": {"BR005":3,"BR007":3,"BR009":2,"BR011":2,"BR013":2,"BR015":1,"BR016":1,"BR017":1,
                     "BR019":2,"BR021": 2,"BR020":3,"BR022":3,"Hallway1":2,"Hallway2":2},

    "rightHallway1": {"BR046":3,"BR051":2,"Rmens": 2, "BR055": 1,"BR056":2,"BR054":2,"Hallway1":2,"Hallway2":2},

    "rightHallway2": {"stairR3":2,"BR090": 1,"BR070":3,"BR072":3,"BR074":3,"BR071":4,"BR073":4,"BR076":4,"Hallway1":2,"Hallway2":2},

    "rightHallway3": {"BR083": 1,"BR085": 1, "BR087": 2, "BR089": 2,"BR091":3,"BR081": 2, "BR079": 2, "BR077":3,"BR078":3, 
                      "BR075":3,"Hallway1":2,"Hallway2":2},

    "Hallway2":{ "BR061":1,"BR059":1,"BR063":2,"BR065":3,"BR066":3,"BR064":3,"BR062":3,"BR060":3,"BR058":1,
                 "BR056":2,"BR054":3,"BR057": 2,"leftHallway1":3,"rightHallway1":3},
                     
    "Hallway3":{"stairR2":1,"BR054":2,"BR055":3,"BR089":2,"rightHallway1":3,"rightHallway3":2,"rightHallway2":1},

    # room nodes
    "BR001": {"leftHallway1": 1},
    "BR003": {"leftHallway1": 1},
    "BR005": {"leftHallway2": 1},
    "BR007": {"leftHallway2": 2},
    "BR009": {"leftHallway2": 3},
    "BR011": {"leftHallway2": 2},
    "BR013": {"leftHallway2": 1},
    "BR015": {"leftHallway2": 0},
    "BR017": {"leftHallway2": 1},
    "BR016":{"leftHallway2":1},
    "BR019": {"leftHallway2": 2},
    "BR021": {"leftHallway2": 3},
    "BR010": {"leftHallway1": 2},
    "BR018": {"leftHallway1": 1},
    "BR020": {"leftHallway2": 3},
    "BR022": {"leftHallway2": 3},
    "BR023": {"leftHallway1": 2},
    "BR024":{"leftHallway1":2},
    "BR068":{"leftHallway1":3},
    "BR067":{"leftHallway1":3},
    "BR066": {"Hallway2": 3},
    "BR064": {"Hallway2": 3},
    "BR065": {"Hallway2": 3},
    "BR063": {"Hallway2": 2},
    "BR062":{"Hallway2":3},
    "BR061": {"Hallway2": 1},
    "BR060": {"Hallway2":3},
    "BR059": {"Hallway2": 1},
    "BR058":{"Hallway2":1},
    "BR057": {"Hallway2": 2},
    "BR055": {"rightHallway1": 1},
    "BR054": {"rightHallway1": 2},
    "BR025": {"Hallway1": 3},
    "BR026": {"Hallway1": 3},
    "BR032": {"Hallway1": 2},
    "BR043":{"Hallway1":2},
    "BR045": {"Hallway1": 1},
    "BR047": {"Hallway1": 1},
    "BR046": {"Hallway1": 2},
    "BR050": {"Hallway1": 3},
    "BR051":{"rightHallway1":2},
    "BR048": {"Hallway1": 3},
    "BR090": {"rightHallway2": 1},
    "BR091":{"rightHallway3":3},
    "BR070": {"Hallway1": 4,"rightHallway2": 3},
    "BR080": {"Hallway1": 4},
    "BR071": {"rightHallway2": 4},
    "BR073": {"rightHallway2": 4},
    "BR075": {"rightHallway3": 3},
    "BR077": {"rightHallway3": 3},
    "BR079": {"rightHallway3": 2},
    "BR081": {"rightHallway3": 2},
    "BR076": {"rightHallway3": 3},
    "BR078": {"rightHallway3": 3},
    "BR083": {"Hallway1": 5},
    "BR089": {"rightHallway3": 2},
    "BR087": {"rightHallway3": 2},
    "BR085": {"rightHallway3": 1},
    "BR041": {"Hallway1": 2},
    "BR029": {"Hallway1": 2},
    "BR040": {"Hallway1": 1},
    "BR072": {"rightHallway2": 3},
    "BR074": {"rightHallway2": 3},
    "BR056": {"rightHallway1": 2},
    "Rmens": {"rightHallway1": 2},
    "Lwomens": {"Hallway1": 2},
}

# %%
BH1_floorplan = {
    #entry nodes
    "frontEntrance": {"Hallway1": 1, "BR145": 1},
    "backEntrance": {"stairR3": 1},
    "stairL1":{"Hallway1":3},
    "stairL2":{"leftHallway3":5},
    "stairR1":{"Hallway1":3},
    "stairR2":{"rightHallway3":4},
    "stairR3":{"rightHallway2":4,"backEntrance":1},
    
    #hall nodes
    "Hallway1": {
        "frontEntrance": 1, "BR132": 1, "BR126": 2, "BR125": 2, "stairL1": 3, "BR100": 5, "BR110": 5, "BR112": 5, 
        "leftHallway2": 2, "leftHallway3": 4, "leftHallway4": 6, "BR142": 1, "BR146": 2, "stairR1": 3, 
        "BR150": 3, "BR176": 5, "BR170": 5, "rightHallway2": 2, "rightHallway3": 4, "rightHallway4": 6},
    
    "leftHallway2": {"Hallway1": 2, "Lwomens": 1, "Lmens": 2, "BR133": 3, "LHHallUpper": 4},
    
    "LHHallUpper": {"BR139": 1, "BR135": 1, "leftHallway2": 4, "leftHallway3": 2},
    
    "leftHallway3": {"Hallway1": 4, "BR116": 1, "BR120": 2, "BR122": 3, "BR124": 4, "elevator": 4, "stairL2": 5, 
                      "BR100": 1, "BR102": 2, "BR104": 2, "BR101": 3, "LHHallLower": 3, "LHHallUpper": 3},
    
    "leftHallway4": {"Hallway1": 6, "BR113": 1, "BR111": 2, "BR109": 3, "BR107": 4, "LHHallLower": 4,
                      "BR115": 1, "BR117": 2, "BR119": 3, "BR121": 4, "LHHallUpper": 4},
    
    "LHHallLower": {"BR103": 1, "BR105": 1, "leftHallway4": 4, "leftHallway3": 3},
    
    "rightHallway2": {"Hallway1": 2, "Rwomens": 1, "Rmens": 2, "BR157": 3, "BR159": 4, "BR160": 4, "stairR3": 4},
    
    "rightHallway3": {"Hallway1": 4, "BR172": 2, "BR174": 2, "BR171": 3, "RHHallLower": 3, "BR180": 1, 
                       "BR156": 3, "BR160": 4, "stairR2": 4, "BR190": 3, "RHHallUpper": 3},
    
    "rightHallway4": {"Hallway1": 6, "BR183": 1, "BR181": 3, "BR179": 4, "BR177": 4, "RHHallLower": 3,
                       "BR185": 1, "BR187": 2, "BR189": 3, "BR191": 4, "RHHallUpper": 3},
    
    "RHHallUpper": {"BR197": 1, "BR195": 1, "BR193": 1, "rightHallway3": 3, "rightHallway4": 3},
    
    "RHHallLower": {"BR175": 1, "BR173": 1, "rightHallway3": 3, "rightHallway4": 3},

    # room nodes
    "BR145": {"frontEntrance": 1},
    "BR132": {"Hallway1": 1},
    "BR126": {"Hallway1": 2},
    "BR125": {"Hallway1": 2},
    "BR100": {"Hallway1": 5, "leftHallway3": 1},
    "BR110": {"Hallway1": 5},
    "BR112": {"Hallway1": 5},
    "BR142": {"Hallway1": 1},
    "BR146": {"Hallway1": 2},
    "BR150": {"Hallway1": 3},
    "BR176": {"Hallway1": 5},
    "BR170": {"Hallway1": 5},
    "Lwomens": {"leftHallway2": 1},
    "Lmens": {"leftHallway2": 2},
    "BR133": {"leftHallway2": 3},
    "BR139": {"LHHallUpper": 1},
    "BR135": {"LHHallUpper": 1},
    "BR116": {"leftHallway3": 1},
    "BR120": {"leftHallway3": 2},
    "BR122": {"leftHallway3": 3},
    "BR124": {"leftHallway3": 4},
    "elevator": {"leftHallway3": 4},
    "BR102": {"leftHallway3": 2},
    "BR104": {"leftHallway3": 2},
    "BR101": {"leftHallway3": 3},
    "BR103": {"LHHallLower": 1},
    "BR105": {"LHHallLower": 1},
    "BR113": {"leftHallway4": 1},
    "BR111": {"leftHallway4": 2},
    "BR109": {"leftHallway4": 3},
    "BR107": {"leftHallway4": 4},
    "BR115": {"leftHallway4": 1},
    "BR117": {"leftHallway4": 2},
    "BR119": {"leftHallway4": 3},
    "BR121": {"leftHallway4": 4},
    "Rwomens": {"rightHallway2": 1},
    "Rmens": {"rightHallway2": 2},
    "BR157": {"rightHallway2": 3},
    "BR159": {"rightHallway2": 4},
    "BR160": {"rightHallway2": 4},
    "BR172": {"rightHallway3": 2},
    "BR174": {"rightHallway3": 2},
    "BR171": {"rightHallway3": 3},
    "BR180": {"rightHallway3": 1},
    "BR156": {"rightHallway3": 3},
    "BR190": {"rightHallway3": 3},
    "BR183": {"rightHallway4": 1},
    "BR181": {"rightHallway4": 3},
    "BR179": {"rightHallway4": 4},
    "BR177": {"rightHallway4": 4},
    "BR185": {"rightHallway4": 1},
    "BR187": {"rightHallway4": 2},
    "BR189": {"rightHallway4": 3},
    "BR191": {"rightHallway4": 4},
    "BR197": {"RHHallUpper": 1},
    "BR195": {"RHHallUpper": 1},
    "BR193": {"RHHallUpper": 1},
    "BR175": {"RHHallLower": 1},
    "BR173": {"RHHallLower": 1},
}

# %%
BH2_floorplan = {
    # entry nodes
    "stairL1": {"Hallway1": 3},
    "stairL2": {"leftHallway3": 3},
    "stairR1": {"Hallway1": 3},
    "stairR2": {"rightHallway3": 3},
    "elevator": {"leftHallway3": 3},

    # hall nodes
    "Hallway1": {
        "BR240": 1, "BR226": 2, "BR243": 2, "BR225": 3, "BR200": 3, "BR210": 3, "BR215": 4,
        "leftHallway2": 2, "leftHallway3": 3, "leftHallway4": 4,
        "stairL1": 3, "stairR1": 3,
        "BR245": 1, "BR247": 2, "BR248": 2, "BR242": 2, "BR244": 3, "BR246": 3, "BR250": 3,
        "BR280": 4, "BR283": 4,
        "rightHallway2": 2, "rightHallway3": 3, "rightHallway4": 4
    },

    "leftHallway2": {"Hallway1": 1, "BR227": 1, "Lwomens": 1, "Lmens": 2, "BR223": 2, "LHHallUpper": 3, "BR237": 3, "BR239": 3},
    "LHHallUpper": {"BR235": 1, "BR239": 1, "leftHallway2": 3, "leftHallway3": 3},
    "leftHallway3": {"Hallway1": 3, "elevator": 3, "stairL2": 3, "BR224": 3, "BR222": 2, "BR220": 3, "BR210": 4, "BR200": 5, "LHHallUpper": 1},
    "leftHallway4": {"Hallway1": 4, "BR219": 1, "BR22": 1, "BR217": 2, "BR215": 3, "LHHallUpper": 1},

    "rightHallway2": {"Hallway1": 2, "BR249": 2, "Rwomens": 1, "Rmens": 1, "BR257": 1, "BR259": 2, "BR248": 3},
    "rightHallway3": {"Hallway1": 3, "BR290": 2, "BR297": 3, "BR260": 3, "BR262": 3, "BR270": 3, "BR261": 4, "BR272": 4, "BR274": 4, "BR271": 5},
    "rightHallway4": {"Hallway1": 4, "BR283": 1, "BR285": 1, "BR281": 2, "BR279": 2, "BR275": 3, "BR277": 3, "BR287": 2, "BR289": 2, "BR291": 3, "BR295": 3},

    # room nodes
    "BR240": {"Hallway1": 1},
    "BR226": {"Hallway1": 2},
    "BR243": {"Hallway1": 2},
    "BR225": {"Hallway1": 3},
    "BR200": {"Hallway1": 3, "leftHallway3": 5},
    "BR210": {"Hallway1": 3, "leftHallway3": 4},
    "BR215": {"Hallway1": 4, "leftHallway4": 3},
    "BR245": {"Hallway1": 1},
    "BR247": {"Hallway1": 2},
    "BR248": {"Hallway1": 2, "rightHallway2": 3},
    "BR242": {"Hallway1": 2},
    "BR244": {"Hallway1": 3},
    "BR246": {"Hallway1": 3},
    "BR250": {"Hallway1": 3},
    "BR280": {"Hallway1": 4},
    "BR283": {"Hallway1": 4, "rightHallway4": 1},
    "BR227": {"leftHallway2": 1},
    "Lwomens": {"leftHallway2": 1},
    "Lmens": {"leftHallway2": 2},
    "BR223": {"leftHallway2": 2},
    "BR237": {"leftHallway2": 3},
    "BR239": {"leftHallway2": 3, "LHHallUpper": 1},
    "BR235": {"LHHallUpper": 1},
    "BR224": {"leftHallway3": 3},
    "BR222": {"leftHallway3": 2},
    "BR220": {"leftHallway3": 3},
    "BR219": {"leftHallway4": 1},
    "BR22": {"leftHallway4": 1},
    "BR217": {"leftHallway4": 2},
    "BR249": {"rightHallway2": 2},
    "Rwomens": {"rightHallway2": 1},
    "Rmens": {"rightHallway2": 1},
    "BR257": {"rightHallway2": 1},
    "BR259": {"rightHallway2": 2},
    "BR290": {"rightHallway3": 2},
    "BR297": {"rightHallway3": 3},
    "BR260": {"rightHallway3": 3},
    "BR262": {"rightHallway3": 3},
    "BR270": {"rightHallway3": 3},
    "BR261": {"rightHallway3": 4},
    "BR272": {"rightHallway3": 4},
    "BR274": {"rightHallway3": 4},
    "BR271": {"rightHallway3": 5},
    "BR285": {"rightHallway4": 1},
    "BR281": {"rightHallway4": 2},
    "BR279": {"rightHallway4": 2},
    "BR275": {"rightHallway4": 3},
    "BR277": {"rightHallway4": 3},
    "BR287": {"rightHallway4": 2},
    "BR289": {"rightHallway4": 2},
    "BR291": {"rightHallway4": 3},
    "BR295": {"rightHallway4": 3}
}

# %%
BH3_floorplan = {
    # entry nodes
    "stairL1": {"Hallway1": 3},
    "stairL2": {"leftHallway1": 3},
    "stairR1": {"Hallway1": 3},
    "stairR2": {"rightHallway1": 3},
    "elevator": {"leftHallway1": 3},

    # hall nodes
    "Hallway1": {
        "BR340": 1, "BR336": 2,"stairL1":3,"BR310":4,"leftHallway1":3,"BR314":4,"leftHallway2":4,
        "BR313":4,"BR325":3, "BR327":3,"BR329":3,"BR331":2,"BR333":2,"Lwomens":2,"BR341":2,
        "BR343":2,"BR345":2,"BR347":1,"BR349":1,"BR351":1,"BR353":1,"BR355":2,"BR359":2,"Rmens":2,
        "BR361":3,"BR363":3,"BR365":3,"BR367":3,"BR369":3,"rightHallway1":3,"BR380":4,"rightHallway2":4,
        "BR383":4,"BR350":2,"BR352":2,"BR354":2,"BR360":2,"BR362":3,"BR364":3,"BR366":3,"stairR1":3,"BR370":3, 
    },

    "leftHallway1": {
        "Hallway1": 3, "BR320": 1,"BR322":2,"BR324":3,"elevator":3,"stairL2":3,"BR310":2,"BR304":2,
        "BR302":3,"BR301":3,"BR303":3 
    },

    "leftHallway2": {
        "Hallway1": 4,"BR313":1,"BR311":2,"BR309":2,"BR307":3,"BR305":3,"BR303":3,
        "BR315":1,"BR317":2,"BR319":2,"BR321":3,"BR322":3
    },

    "rightHallway1": {
        "Hallway1": 3,"BR388":2,"BR390":2,"stairR2":2,"BR397":3,"BR370":2,"BR372":2,
        "BR374":3,"BR371":3,"BR373":3
    },

    "rightHallway2": {
        "Hallway1": 4,"BR383":1,"BR381":2,"BR379":2,"BR377":3,"BR375":3,"BR385":1,
        "BR387":2,"BR389":2,"BR391":3,"BR393":3,"BR395":3,"stairR2":3
    },

    # room nodes
    "BR301": {"leftHallway1": 3},
    "BR302": {"leftHallway1": 3},
    "BR303": {"leftHallway1": 3, "leftHallway2": 3},
    "BR304": {"leftHallway1": 2},
    "BR305": {"leftHallway2": 3},
    "BR307":{"leftHallway2":3},
    "BR309": {"leftHallway2": 2},
    "BR310": {"Hallway1": 4, "leftHallway1": 2},
    "BR311": {"leftHallway2": 2},
    "BR313": {"Hallway1": 4, "leftHallway2": 1},
    "BR314": {"Hallway1": 4},
    "BR315": {"leftHallway2": 1},
    "BR317": {"leftHallway2": 2},
    "BR319": {"leftHallway2": 2},
    "BR320": {"leftHallway1": 1},
    "BR321": {"leftHallway2": 3},
    "BR322": {"leftHallway1": 2, "leftHallway2": 3},
    "BR324": {"leftHallway1": 3},
    "BR325": {"Hallway1": 3},
    "BR327": {"Hallway1": 3},
    "BR329": {"Hallway1": 3},
    "BR331": {"Hallway1": 2},
    "BR333": {"Hallway1": 2},
    "BR336": {"Hallway1": 2},
    "BR340": {"Hallway1": 1},
    "BR341": {"Hallway1": 2},
    "BR343": {"Hallway1": 2},
    "BR345": {"Hallway1": 2},
    "BR347": {"Hallway1": 1},
    "BR349": {"Hallway1": 1},
    "BR350": {"Hallway1": 2},
    "BR351": {"Hallway1": 1},
    "BR352": {"Hallway1": 2},
    "BR353": {"Hallway1": 1},
    "BR354": {"Hallway1": 2},
    "BR355": {"Hallway1": 2},
    "BR359": {"Hallway1": 2},
    "BR360": {"Hallway1": 2},
    "BR361": {"Hallway1": 3},
    "BR362": {"Hallway1": 3},
    "BR363": {"Hallway1": 3},
    "BR364": {"Hallway1": 3},
    "BR365": {"Hallway1": 3},
    "BR366": {"Hallway1": 3},
    "BR367": {"Hallway1": 3},
    "BR369": {"Hallway1": 3},
    "BR370": {"Hallway1": 3, "rightHallway1": 2},
    "BR372": {"rightHallway1": 2},
    "BR374": {"rightHallway1": 3},
    "BR371": {"rightHallway1": 3},
    "BR373": {"rightHallway1": 3},
    "BR375": {"rightHallway2": 3},
    "BR377": {"rightHallway2": 3},
    "BR379": {"rightHallway2": 2},
    "BR380": {"Hallway1": 4},
    "BR381": {"rightHallway2": 2},
    "BR383": {"Hallway1": 4, "rightHallway2": 1},
    "BR385": {"rightHallway2": 1},
    "BR387": {"rightHallway2": 2},
    "BR388": {"rightHallway1": 2},
    "BR389": {"rightHallway2": 2},
    "BR390": {"rightHallway1": 2},
    "BR391": {"rightHallway2": 3},
    "BR393": {"rightHallway2": 3},
    "BR395": {"rightHallway2": 3},
    "BR397": {"rightHallway1": 3},
    "Lwomens": {"Hallway1": 2},
    "Rmens": {"Hallway1": 2}, 
}

# %%
BH4_floorplan = {
    # entry nodes
    "stairL1": {"Hallway1": 3,"leftHallway1": 3},
    "stairL2": {"leftHallway1": 2},
    "stairR1": {"Hallway1": 3,"miniHallR":3},
    "elevator": {"leftHallway1": 3},

    # hall nodes
    "Hallway1": {
        "BR440":1,"BR426":2,"stairL1":3,"BR490":3,"Lwomens":2,"Lmens":2,"BR441":2,
        "BR443":1,"BR445":1,"BR447":2,"BR449":2,"BR451":3,"BR456":3,"stairR1":3,
        "BR454":3,"BR452":3,"BR450":3,"BR448":2,"BR446":2,"BR444":1,"BR442":1,"miniHallL":2,"leftHallway1":3
    },

    "leftHallway1": {
        "Hallway1": 3, "stairL2": 2, "elevator": 2,"stairL1":3
    },

    "Hallway2": {
        "BR443":1,"Lwomens":2,"BR490":3,"BR488":3,"BR486":3,"BR484":2,"BR482":2,
        "BR480":2,"BR478":1,"BR476":1,"BR474":1,"BR472":1,"BR470":2,"BR468":2,
        "BR466":2,"BR464":2,"BR462":3,"BR460":3,"BR458":3,"BR467":2,"BR469":2,"BR445":1,"miniHallL":2
    },
    "miniHallL":{"Hallway1":2,"Hallway2":2},
    "miniHallR":{"Hallway1":2,"Hallway2":2,"stairR1":3},

    # room nodes
    "BR440": {"Hallway1":1},
    "BR426": {"Hallway1":2},
    "BR490": {"Hallway1":3, "Hallway2":3},
    "Lwomens": {"Hallway1":2, "Hallway2":2},
    "Lmens": {"Hallway1":2},
    "BR441": {"Hallway1":2},
    "BR443": {"Hallway1":1, "Hallway2":1},
    "BR445": {"Hallway1":1, "Hallway2":1},
    "BR447": {"Hallway1":2},
    "BR449": {"Hallway1":2},
    "BR451": {"Hallway1":3},
    "BR456": {"Hallway1":3},
    "BR454": {"Hallway1":3},
    "BR452": {"Hallway1":3},
    "BR450": {"Hallway1":3},
    "BR448": {"Hallway1":2},
    "BR446": {"Hallway1":2},
    "BR444": {"Hallway1":1},
    "BR442": {"Hallway1":1},
    "BR488": {"Hallway2":3},
    "BR486": {"Hallway2":3},
    "BR484": {"Hallway2":2},
    "BR482": {"Hallway2":2},
    "BR480": {"Hallway2":2},
    "BR478": {"Hallway2":1},
    "BR476": {"Hallway2":1},
    "BR474": {"Hallway2":1},
    "BR472": {"Hallway2":1},
    "BR470": {"Hallway2":2},
    "BR468": {"Hallway2":2},
    "BR466": {"Hallway2":2},
    "BR464": {"Hallway2":2},
    "BR462": {"Hallway2":3},
    "BR460": {"Hallway2":3},
    "BR458": {"Hallway2":3},
    "BR467": {"Hallway2":2},
    "BR469": {"Hallway2":2},
}

# %%
def connect_multiple_floors_v2(all_floorplans, connectors_by_floor, connector_weight=1, direct_room_connections=False):
    building_graph = {}
    floor_graphs = {}

    for floor, floorplan in enumerate(all_floorplans):
        floor_name = f"Floor{floor + 1}"
        floor_graph = {}
        for node, neighbors in floorplan.items():
            floor_graph[f"{node}_F{floor + 1}"] = {f"{neighbor}_F{floor + 1}": weight for neighbor, weight in neighbors.items()}
        floor_graphs[floor_name] = floor_graph
        building_graph.update(floor_graph)

    # Connect vertical connectors
    common_connectors = set(connectors_by_floor[0]).intersection(*connectors_by_floor[1:])
    for connector in common_connectors:
        for i in range(len(all_floorplans) - 1):
            floor1 = i + 1
            floor2 = i + 2
            node1 = f"{connector}_F{floor1}"
            node2 = f"{connector}_F{floor2}"
            building_graph[node1] = building_graph.get(node1, {})
            building_graph[node1][node2] = connector_weight
            building_graph[node2] = building_graph.get(node2, {})
            building_graph[node2][node1] = connector_weight

            # Connect hallways to connector nodes
            for hallway, neighbors in all_floorplans[i].items():
                if connector in neighbors:
                    hallway_node = f"{hallway}_F{floor1}"
                    connector_node = f"{connector}_F{floor1}"
                    building_graph[hallway_node] = building_graph.get(hallway_node, {})
                    building_graph[hallway_node][connector_node] = neighbors[connector]
                    building_graph[connector_node] = building_graph.get(connector_node, {})
                    building_graph[connector_node][hallway_node] = neighbors[connector]

            for hallway, neighbors in all_floorplans[i+1].items():
                if connector in neighbors:
                    hallway_node = f"{hallway}_F{floor2}"
                    connector_node = f"{connector}_F{floor2}"
                    building_graph[hallway_node] = building_graph.get(hallway_node, {})
                    building_graph[hallway_node][connector_node] = neighbors[connector]
                    building_graph[connector_node] = building_graph.get(connector_node, {})
                    building_graph[connector_node][hallway_node] = neighbors[connector]

    # Handle direct room connections across floors (if enabled)
    if direct_room_connections:
        for floor_index, floorplan in enumerate(all_floorplans):
            for room, neighbors in floorplan.items():
                if not room.lower().startswith(("stair", "elevator", "hallway", "mini")): # Basic room identification
                    for neighbor, weight in neighbors.items():
                        if neighbor in all_floorplans[(floor_index + 1) % len(all_floorplans)]: # Check if neighbor exists on the next floor (wrapping around for simplicity)
                            room_node_current = f"{room}_F{floor_index + 1}"
                            room_node_next = f"{neighbor}_F{(floor_index + 1) % len(all_floorplans) + 1}"
                            building_graph[room_node_current] = building_graph.get(room_node_current, {})
                            building_graph[room_node_current][room_node_next] = weight # Or some defined cross-floor weight
                            building_graph[room_node_next] = building_graph.get(room_node_next, {})
                            building_graph[room_node_next][room_node_current] = weight

    return building_graph

# %%
floors = [BH0_floorplan, BH1_floorplan, BH2_floorplan, BH3_floorplan, BH4_floorplan]

connectors_by_floor = [
    ['elevator','stairL1','stairL2','stairR1','stairR2','stairR3'],  # Floor 0
    ['elevator','stairL1','stairL2','stairR1','stairR2','stairR3'],  # Floor 1
    ['elevator','stairL1','stairL2','stairR1','stairR2'],  # Floor 2
    ['elevator','stairL1','stairL2','stairR1','stairR2'],  # Floor 3
    ['elevator','stairL1','stairL2','stairR1'],  # Floor 4
]

building_graph = connect_multiple_floors_v2(floors, connectors_by_floor)

# %%
import heapq

def dijkstra(graph, start_base, end_base):
    start_nodes = [node for node in graph if node.startswith(start_base + "_F")]
    end_nodes = [node for node in graph if node.startswith(end_base + "_F")]

    if not start_nodes:
        raise KeyError(f"Start room '{start_base}' not found on any floor.")
    start_node = start_nodes[0]

    if not end_nodes:
        raise KeyError(f"End room '{end_base}' not found on any floor.")
    end_node = end_nodes[0]

    distances = {node: float('inf') for node in graph}
    distances[start_node] = 0
    priority_queue = [(0, start_node, [start_node])]

    while priority_queue:
        current_distance, current_node, raw_path = heapq.heappop(priority_queue)

        if current_node == end_node:
            formatted_path = []
            i = 0
            while i < len(raw_path):
                node = raw_path[i]
                base_node = node.split("_F")[0]
                formatted_path.append(base_node)

                if i < len(raw_path) - 1:
                    current_base = base_node
                    next_base = raw_path[i+1].split("_F")[0]
                    current_floor = int(node.split("_F")[-1])
                    next_floor = int(raw_path[i+1].split("_F")[-1])

                    if current_base.lower().startswith(("stair", "elevator")) and current_base == next_base and current_floor != next_floor:
                        formatted_path[-1] = f"{current_base}"  # Just show the connector name
                        i += 1
                    elif current_base.lower().startswith(("stair", "elevator")) and current_base != next_base and current_floor != next_floor:
                        formatted_path[-1] = f"{current_base} (Floor {current_floor})" # Indicate starting floor
                    elif current_base != next_base and next_base.lower().startswith(("stair", "elevator")) and current_floor != next_floor:
                        pass

                i += 1

            final_formatted_path = []
            i = 0
            while i < len(formatted_path):
                node = formatted_path[i]
                final_formatted_path.append(node)
                if i < len(formatted_path) - 1:
                    if not (formatted_path[i].lower().startswith(("stair", "elevator")) and formatted_path[i+1].lower().startswith(("stair", "elevator"))):
                        final_formatted_path.append("->")
                i += 1

            return "->".join(final_formatted_path), current_distance

        if current_distance > distances[current_node]:
            continue

        for neighbor, weight in graph.get(current_node, {}).items():
            distance = current_distance + weight
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                heapq.heappush(priority_queue, (distance, neighbor, raw_path + [neighbor]))

    return None, float('inf')

# Example Usage:
start_room = "BR440"
end_room = "BR220"
try:
    formatted_path, distance = dijkstra(building_graph, start_room, end_room)
    if formatted_path:
        print(f"Shortest path: {formatted_path}")
        print(f"Distance: {distance}")
    else:
        print(f"No path found from {start_room} to {end_room}")
except KeyError as e:
    print(f"Error: {e}")
# Out:
# Shortest path: BR440->->->Hallway1->->->leftHallway1->->->elevator->elevator->->->leftHallway3->->->BR220
# Distance: 14
