# %%
#creation of nodes/edges graph to represent rooms/hallways

# %%
import math
import heapq

BH1_floorplan = {
    "Entrance": {"Hallway1": 0, "room145": 1},
    
    "Hallway1": {
        "Entrance": 0, "room132": 1, "room126": 2, "room125": 2, "leftStairs": 3, "room100": 5, "room110": 5, "room112": 5, 
        "leftHallway2": 2, "leftHallway3": 4, "leftHallway4": 6, "room142": 1, "room146": 2, "rightStairs": 3, 
        "room150": 3, "room176": 5, "room170": 5, "rightHallway2": 2, "rightHallway3": 4, "rightHallway4": 6},
    
    "leftHallway2": {"Hallway1": 2, "Lwomens": 1, "Lmens": 2, "room133": 3, "LHHallUpper": 4},
    
    "LHHallUpper": {"room139": 1, "room135": 1, "leftHallway2": 4, "leftHallway3": 2},
    
    "leftHallway3": {"Hallway1": 4, "room116": 1, "room120": 2, "room122": 3, "room124": 4, "elevator": 4, "leftUpperStairs": 5, 
                      "room100": 1, "room102": 2, "room104": 2, "room101": 3, "LHHallLower": 3, "LHHallUpper": 3},
    
    "leftHallway4": {"Hallway1": 6, "room113": 1, "room111": 2, "room109": 3, "room107": 4, "LHHallLower": 4,
                      "room115": 1, "room117": 2, "room119": 3, "room121": 4, "LHHallUpper": 4},
    
    "LHHallLower": {"room103": 1, "room105": 1, "leftHallway4": 4, "leftHallway3": 3},
    
    "rightHallway2": {"Hallway1": 2, "Rwomens": 1, "Rmens": 2, "room157": 3, "room159": 4, "room160": 4},
    
    "rightHallway3": {"Hallway1": 4, "room172": 2, "room174": 2, "room171": 3, "RHHallLower": 3, "room180": 1, 
                       "room156": 3, "room160": 4, "rightUpperStairs": 4, "room190": 3, "RHHallUpper": 3},
    
    "rightHallway4": {"Hallway1": 6, "room183": 1, "room181": 3, "room179": 4, "room177": 4, "RHHallLower": 3,
                       "room185": 1, "room187": 2, "room189": 3, "room191": 4, "RHHallUpper": 3},
    
    "RHHallUpper": {"room197": 1, "room195": 1, "room193": 1, "rightHallway3": 3, "rightHallway4": 3},
    
    "RHHallLower": {"room175": 1, "room173": 1, "rightHallway3": 3, "rightHallway4": 3},

    #adding stairs connections between floors
    "rightStairs": {"rightStairs_0": 1, "rightStairs_2": 1, "rightStairs_3": 2, "rightStairs_4": 3, "Hallway1": 3, "rightHallway3": 0},
    "leftStairs": {"leftStairs_0": 1, "leftStairs_2": 1, "leftStairs_3": 2, "leftStairs_4": 3, "Hallway1": 3, "leftHallway3": 0},
    "rightUpperStairs": {"rightUpperStairs_0": 1, "rightUpperStairs_2": 1, "rightUpperStairs_3": 2},
    "leftUpperStairs": {"leftUpperStairs_0": 1, "leftUpperStairs_2": 1, "leftUpperStairs_3": 2, "leftUpperStairs_4": 3},

    "rightStairs_0": {"rightStairs": 1, "rightStairs_2": 2, "rightStairs_3": 3, "rightStairs_4": 4},
    "leftStairs_0": {"leftStairs": 1, "leftStairs_2": 2, "leftStairs_3": 3, "leftStairs_4": 4},
    "rightUpperStairs_0": {"rightUpperStairs": 1, "rightUpperStairs_2": 2, "rightUpperStairs_3": 3},
    "leftUpperStairs_0": {"leftUpperStairs": 1, "leftUpperStairs_2": 2, "leftUpperStairs_3": 3, "leftUpperStairs_4": 4},

    "rightStairs_2": {"rightStairs_0": 2, "rightStairs": 1, "rightStairs_3": 1, "rightStairs_4": 2},
    "leftStairs_2": {"leftStairs_0": 2, "leftStairs": 1, "leftStairs_3": 1, "leftStairs_4": 2},
    "rightUpperStairs_2": {"rightUpperStairs_0": 2, "rightUpperStairs": 1, "rightUpperStairs_3": 1},
    "leftUpperStairs_2": {"leftUpperStairs_0": 2, "leftUpperStairs": 1, "leftUpperStairs_3": 1, "leftUpperStairs_4": 2},

    "rightStairs_3": {"rightStairs_0": 3, "rightStairs_2": 1, "rightStairs": 2, "rightStairs_4": 1},
    "leftStairs_3": {"leftStairs_0": 3, "leftStairs_2": 1, "leftStairs": 2, "leftStairs_4": 1},
    "rightUpperStairs_3": {"rightUpperStairs_0": 3, "rightUpperStairs": 2, "rightUpperStairs_2": 1},
    "leftUpperStairs_3": {"leftUpperStairs_0": 3, "leftUpperStairs": 2, "leftUpperStairs_2": 1, "leftUpperStairs_4": 1},

    "rightStairs_4": {"rightStairs_0": 4, "rightStairs_2": 2, "rightStairs_3": 1, "rightStairs": 3},
    "leftStairs_4": {"leftStairs_0": 4, "leftStairs_2": 2, "leftStairs_3": 1, "leftStairs": 3},
    "leftUpperStairs_4": {"leftUpperStairs_0": 4, "leftUpperStairs_2": 2, "leftUpperStairs_3": 1, "leftUpperStairs": 3},


    # Connecting each room to its corresponding hallway
    "room145": {"Entrance": 1},
    "room132": {"Hallway1": 1},
    "room126": {"Hallway1": 2},
    "room125": {"Hallway1": 2},
    "room100": {"Hallway1": 5, "leftHallway3": 1},
    "room110": {"Hallway1": 5},
    "room112": {"Hallway1": 5},
    "room142": {"Hallway1": 1},
    "room146": {"Hallway1": 2},
    "room150": {"Hallway1": 3},
    "room176": {"Hallway1": 5},
    "room170": {"Hallway1": 5},
    "Lwomens": {"leftHallway2": 1},
    "Lmens": {"leftHallway2": 2},
    "room133": {"leftHallway2": 3},
    "room139": {"LHHallUpper": 1},
    "room135": {"LHHallUpper": 1},
    "room116": {"leftHallway3": 1},
    "room120": {"leftHallway3": 2},
    "room122": {"leftHallway3": 3},
    "room124": {"leftHallway3": 4},
    "elevator": {"leftHallway3": 4},
    "leftUpperStairs": {"leftHallway3": 5},
    "room102": {"leftHallway3": 2},
    "room104": {"leftHallway3": 2},
    "room101": {"leftHallway3": 3},
    "room103": {"LHHallLower": 1},
    "room105": {"LHHallLower": 1},
    "room113": {"leftHallway4": 1},
    "room111": {"leftHallway4": 2},
    "room109": {"leftHallway4": 3},
    "room107": {"leftHallway4": 4},
    "room115": {"leftHallway4": 1},
    "room117": {"leftHallway4": 2},
    "room119": {"leftHallway4": 3},
    "room121": {"leftHallway4": 4},
    "Rwomens": {"rightHallway2": 1},
    "Rmens": {"rightHallway2": 2},
    "room157": {"rightHallway2": 3},
    "room159": {"rightHallway2": 4},
    "room160": {"rightHallway2": 4},
    "room172": {"rightHallway3": 2},
    "room174": {"rightHallway3": 2},
    "room171": {"rightHallway3": 3},
    "room180": {"rightHallway3": 1},
    "room156": {"rightHallway3": 3},
    "rightUpperStairs": {"rightHallway3": 4},
    "room190": {"rightHallway3": 3},
    "room183": {"rightHallway4": 1},
    "room181": {"rightHallway4": 3},
    "room179": {"rightHallway4": 4},
    "room177": {"rightHallway4": 4},
    "room185": {"rightHallway4": 1},
    "room187": {"rightHallway4": 2},
    "room189": {"rightHallway4": 3},
    "room191": {"rightHallway4": 4},
    "room197": {"RHHallUpper": 1},
    "room195": {"RHHallUpper": 1},
    "room193": {"RHHallUpper": 1},
    "room175": {"RHHallLower": 1},
    "room173": {"RHHallLower": 1},

    #Basement Floor Connections Start Here       I attempted to keep the naming reasonably similar by adding _0 to indicate floor 0 (basement) where necessary
    "rightStairs_0": {"rightHallway3_0": 0},
    "leftStairs_0": {"leftHallway3_0": 0},
    "rightUpperStairs_0": {"rightHallway3_0": 3, "rightUpperHall_0":2, "rightHallway4_0": 4, "room090": 2, "room091": 1, "room089": 2, "room088": 2, "room087": 3, "room085": 4},
    
    "leftUpperHall_0": {"room023": 0, "room022": 1, "room066":1, "room064": 2, "room065": 2, "room063": 3, "room061": 4, "room059": 5, "room057": 6, "leftUpperStairs_0": 3, "room018": 2},
    
    "leftHallway3_0": {"room010": 0, "room018": 1, "leftUpperHall_0": 3, "leftLowerHall_0": 3, "room026": 1, "room025": 1,
                       "womensBath_027": 2, "room032": 2, "room045": 4, "room047": 5, "rightHallway2_0": 6, "leftHallway4_0": 2},
    
    "leftHallway4_0": {"room015": 0, "room013": 1, "room011": 2, "room009": 2, "room007": 3, "room017": 1, "room019": 2, "room021": 3, "leftHallway3_0": 2},
    
    "leftLowerHall_0": {"room001": 0, "room003": 1, "room005": 2, "room007": 3},
    
    "rightHallway2_0": {"mensBath_053": 1, "room055": 2, "rightUpperHall_0": 2, "room046": 0, "room048": 1, "rightStairs_0": 2, "rightHallway3_0": 2, "room050": 1},
    
    "rightHallway3_0": {"room080": 0, "room090": 1, "rightLowerHall_0": 2, "rightUpperStairs_0": 2, "room050": 1},
    
    "rightHallway4_0": {"room083": 0, "room081": 1, "room079": 2, "room077": 2, "room085": 1, "room087": 2, "room089": 2, "room091": 3, "room088": 2, "room080": 1},
    
    "rightUpperHall_0": {"room055":0, "vendingMachines": 1, "rightUpperStairs_0": 2, "room054": 1,
                          "room023": 7, "room022": 6, "room066":6, "room064": 5, "room065": 5, "room063": 4, "room061": 3, "room059": 2, "room057": 2},
    
    "rightLowerHall_0": {"room071": 0, "room073": 1, "room075": 1, "room077": 2, "room076": 1, "room078": 1},

    # Connecting each room to its corresponding hallway
    "room001": {"leftLowerHall_0": 0},
    "room003": {"leftLowerHall_0": 1},
    "room005": {"leftLowerHall_0": 1},
    "room007": {"leftLowerHall_0": 2},
    "room009": {"leftHallway4_0": 3},
    "room011": {"leftHallway4_0": 2},
    "room013": {"leftHallway4_0": 1},
    "room015": {"leftHallway4_0": 0},
    "room017": {"leftHallway4_0": 1},
    "room019": {"leftHallway4_0": 2, "leftUpperHall_0": 2},
    "room021": {"leftHallway4_0": 3, "leftUpperHall_0": 2},
    "room010": {"leftHallway3_0": 0},
    "room018": {"leftHallway3_0": 1, "leftUpperHall_0": 2},
    "room020": {"leftUpperHall_0": 1},
    "room022": {"leftUpperHall_0": 1},
    "room023": {"leftUpperHall_0": 0},
    "leftUpperStairs_0": {"leftUpperHall_0": 3},
    "room066": {"leftUpperHall_0": 1, "rightUpperHall_0": 6},
    "room064": {"leftUpperHall_0": 2, "rightUpperHall_0": 5},
    "room065": {"leftUpperHall_0": 2, "rightUpperHall_0": 5},
    "room063": {"leftUpperHall_0": 4, "rightUpperHall_0": 3},
    "room061": {"leftUpperHall_0": 4, "rightUpperHall_0": 3},
    "room059": {"leftUpperHall_0": 5, "rightUpperHall_0": 2},
    "room057": {"leftUpperHall_0": 5, "rightUpperHall_0": 2},
    "room055": {"leftUpperHall_0": 7, "rightUpperHall_0": 0},
    "room054": {"leftUpperHall_0": 6, "rightUpperHall_0": 1},
    "room025": {"leftHallway3_0": 1, "rightHallway2_0": 5},
    "leftStairs_0": {"leftHallway3_0": 0, "rightHallway2_0": 6},
    "room026": {"leftHallway3_0": 2, "rightHallway2_0": 4},
    "room032": {"leftHallway3_0": 2, "rightHallway2_0": 4},
    "womensBath_027": {"leftHallway3_0": 2, "rightHallway2_0": 4},
    "room045": {"leftHallway3_0": 3, "rightHallway2_0": 3},
    "room047": {"leftHallway3_0": 4, "rightHallway2_0": 2},
    "room046": {"leftHallway3_0": 6, "rightHallway2_0": 0},
    "room055": {"rightUpperHall_0": 0, "rightHallway2_0": 3},
    "mensBath_053": {"rightUpperHall_0": 1, "rightHallway2_0": 2},
    "room050": {"rightHallway2_0": 1, "rightHallway3_0": 1},
    "room048": {"rightHallway2_0": 0, "rightHallway3_0": 2},
    "rightStairs_0": {"rightHallway2_0": 2, "rightHallway3_0": 0},
    "room090": {"rightUpperStairs_0": 2, "rightHallway3_0": 1},
    "room080": {"rightHallway4_0": 2, "rightHallway3_0": 1},
    "room071": {"rightLowerHall_0": 0, "rightHallway4_0": 4},
    "room073": {"rightLowerHall_0": 1, "rightHallway4_0": 3},
    "room075": {"rightLowerHall_0": 1, "rightHallway4_0": 3},
    "room077": {"rightLowerHall_0": 2, "rightHallway4_0": 2},
    "room079": {"rightLowerHall_0": 3, "rightHallway4_0": 1},
    "room081": {"rightLowerHall_0": 4, "rightHallway4_0": 0},
    "room076": {"rightLowerHall_0": 1, "rightHallway4_0": 3},
    "room078": {"rightLowerHall_0": 1, "rightHallway4_0": 3},
    "room083": {"rightHallway4_0": 0},
    "room088": {"rightUpperStairs_0": 1, "rightHallway4_0": 3},
    "room091": {"rightUpperStairs_0": 1, "rightHallway4_0": 3},
    "room089": {"rightUpperStairs_0": 1, "rightHallway4_0": 3},
    "room087": {"rightUpperStairs_0": 2, "rightHallway4_0": 2},
    "room085": {"rightUpperStairs_0": 4, "rightHallway4_0": 1},
}

# %%
#function to calculate distance from room to room 

def dijkstra(graph, start, end):
    # Priority queue to store (distance, node)
    pq = [(0, start)]
    distances = {node: float('inf') for node in graph}
    previous_nodes = {node: None for node in graph}
    distances[start] = 0

    while pq:
        current_distance, current_node = heapq.heappop(pq)

        # If we reached the destination, build and return the path
        if current_node == end:
            path = []
            while current_node:
                path.append(current_node)
                current_node = previous_nodes[current_node]
            return path[::-1], distances[end]  # Reverse the path for correct order

        # Explore neighbors
        for neighbor, weight in graph[current_node].items():
            distance = current_distance + weight

            # If a shorter path is found
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                previous_nodes[neighbor] = current_node
                heapq.heappush(pq, (distance, neighbor))

    return None, float('inf')  # No path found

# Example Usage:
start_room = "Entrance"
end_room = "room160"
path, distance = dijkstra(BH1_floorplan, start_room, end_room)

if path:
    print(f"Shortest path from {start_room} to {end_room}: {' -> '.join(path)} (Distance: {distance})")
else:
    print(f"No path found from {start_room} to {end_room}.")
# Out:
# Shortest path from Entrance to room160: Entrance -> Hallway1 -> rightHallway2 -> room160 (Distance: 6)
